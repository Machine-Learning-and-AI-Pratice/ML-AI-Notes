# %% [markdown]
# **What is Python?**
#
# Python is a high-level, general-purpose, dynamically typed and very popular programming language known for its simplicity and readability.Developed by Guido van Rossum and first released in 1991.Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming.

# %%
print("Hello World! I Don't Give a Bug")

# %% [markdown]
# Arthmatic operation
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Difference between / vs. // operator in Python**
#
# / its used to get float value
# // its used to get int value

# %% [markdown]
# **Comparison Operators**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Membership Operator**
#
# IN and Not IN Operation

# %%
#The in operator is used to check if a character/substring/element exists in a sequence or not.
list_1 = [1,2,3,4,5]
i=2
if i in list_1:
  print("IN method")
if i not in list_1:
  print('not in ')
else:
  print(i,'is there in the list',list_1)

# Time Complexity:

# The execution speed of the ‘in’ operator depends on the target object’s type.

# List: O(n), it becomes slower as the number of elements increases.
# Sets: O(1), it does not depend on the number of elements.
#in dict keys are unquie like set So its O(1) for keys and Values its O(n) like list

#another way to check
import operator
print(operator.contains(list_1, 2))

# %% [markdown]
# IS and NOT IS Operator
#
# diff btn == and IS

# %%
#The is operator evaluates to True if the variables on either side of the operator point to the same object in the memory and false otherwise.

lst1 = [1, 2, 3]
lst2 = [1, 2, 3]
lst3 = lst1

str1 = "hello world"
str2 = "hello world"

print(lst1 is lst2)
print(lst1 is lst3)
print(str1 is str2)
print(str1  is not  str2)

#Difference between ‘==’ and ‘is’ Operator
#The equality == operator is used to compare the value of two variables,
#whereas the identities operator is used to compare the memory location of two variables.

# %% [markdown]
# Logical OPeration
#
#
# ![image.png](data:image/png;base64,...)
#
# **Difference between ‘and’ and ‘&’ in Python**
#
# and is a Logical AND that returns True if both the operands are true whereas ‘&‘ is a bitwise operator in Python that acts on bits and performs bit-by-bit operations.

# %% [markdown]
# Bitwise Operator
#
# And &
#
# OR |
#
# Not ^

# %%
a=1
b=0
c=1
print(a&b)
print(b|c)
print(a^c)

# %% [markdown]
# Assignment Operators
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Walrus Operator**
#
# Syntax: a := expression
#
# a = [1, 2, 3, 4, 5]
#
#
# while(x := len(a)) > 2:
#
#     a.pop()
#
#     print(x)

# %% [markdown]
# **Python Variable**
#
# Variables in Python are used to store data values. They act as containers for storing data, which can be used and manipulated throughout a program. In Python, variables do not need explicit declaration to reserve memory space; the declaration happens automatically when you assign a value to a variable.
#
# Note
#
# The value stored in a variable can be changed during program execution.
#
# A Variables in Python is only a name given to a memory location, all the operations done on the variable effects that memory location.

# %% [markdown]
# **Rules for Python variables**
#
# A Python variable name must start with a letter or the underscore character.
#
# A Python variable name cannot start with a number.
#
# A Python variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ ).
#
# Variable in Python names are case-sensitive (name, Name, and NAME are three different variables).
#
# The reserved words(keywords) in Python cannot be used to name the variable in Python.

# %%
Var = "Geeksforgeeks"
print(Var)
# assign to multi variable
a = b = c = 10
print(a, b, c)

# %% [markdown]
# **Can We Use the Same Name for Different Types?** Yes
#
# If we use the same name, the variable starts referring to
# a new value and type.

# %% [markdown]
# **Global Variables:** Global variables are variables that are declared outside of any function. They can be accessed and modified by any function within the same module.

# %%
global_var = "I am global"

def print_global():
    print(global_var)

print_global()  # Output: I am global

# %% [markdown]
# **Local Variables:** Local variables are variables that are declared within a function. They can only be accessed within that function and are not available outside of it.

# %%
def print_local():
    local_var = "I am local"
    print(local_var)

print_local()  # Output: I am local
# print(local_var)  # This would raise an error because local_var is not accessible outside the function.

# %% [markdown]
# **Global keyword in Python**
#
# Python global is a keyword that allows a user to modify a variable outside of the current scope. It is used to create global variables inside a function.
#
# **Rules of global keyword**
#
# If a variable is assigned a value anywhere within the function’s body, it’s assumed to be local unless explicitly declared as global.
#
# Variables that are only referenced inside a function are implicitly global.
#
# We use a global in Python to use a global variable inside a function.
#
# There is no need to use a global keyword in Python outside a function.

# %% [markdown]
# # OOP

# %% [markdown]
# **What is Object-Oriented Programming in Python?**
#
# It aims to implement real-world entities like inheritance, polymorphisms, encapsulation, etc.
#
# The main concept of object-oriented Programming  is to bind the data and the functions that work together as a single unit so that no other part of the code can access this data.
#
# **OOPs Concepts in Python**
#
# Class in Python
#
# Objects in Python
#
# Polymorphism in Python
#
# Encapsulation in Python
#
# Inheritance in Python
#
# Data Abstraction in Python

# %% [markdown]
# **Class in Python?**
#
#
#
# The class can be defined as a collection of objects. It is a logical entity that has some specific attributes and methods.
#
# For example: if you have an employee class, then it should contain an attribute and method, i.e. an email id, name, age, salary, etc.
#
#
# **Some points on Python class:**
#
# Classes are created by keyword class.
#
# Attributes are the variables that belong to a class.
#
# Attributes are always public and can be accessed using the dot (.) operator. Eg.: Myclass.Myattribute

# %%
#Creating an Empty Class in Python
class Test:
  pass

# %% [markdown]
# **Objects in python ?**
#
#  The object is an entity that has a state and behavior associated with it.It may be any real-world object like a mouse, chair, table, pen, etc.in python integer,float list are also objects.
#
#  An object consists of:
#
# State: It is represented by the attributes of an object. It also reflects the properties of an object.
#
# exam:State or Attributes can be considered as the breed, age, or color of the dog.
#
# Behavior: It is represented by the methods of an object. It also reflects the response of an object to other objects.
#
# exam:The behavior can be considered as to whether the dog is eating or sleeping.
#
# Identity: It gives a unique name to an object and enables one object to interact with other objects.
#
# exam:The identity can be considered as the name of the dog.

# %%
# create object

t=test()

# %% [markdown]
# The method is a function that is associated with an object. In Python, a method is not unique to class instances. Any object type can have methods.

# %% [markdown]
# Function VS Method
#
# Function:
#
# A function is a standalone block of code that can be called from anywhere in your program.
#
# It takes input arguments, performs operations, and optionally returns a value.
#
# Functions are defined using the def keyword.
#
# Method:
#
# A method is a function that is associated with an object or class.
#
# It operates on the data within the object or class it belongs to.
#
# Methods are defined within a class and are called using the dot notation on an
# object
#
# In short:
# Functions: Standalone, reusable blocks of code.
# Methods: Functions associated with objects, providing object-specific behavior.

# %% [markdown]
# **self in Python class?**
#
# Self represents the instance of the class. By using the “self”  we can access the attributes and methods of the class in Python. It binds the attributes with the given arguments.
#
# Note:
#
# Yes, it is mandatory to write self as the first parameter in instance methods of a class in Python.
#
# While the name self is a convention, it is not a keyword, and you can technically use any name, but it must be the first parameter of the method.
#
# Using self is a widely accepted convention and improves code readability.

# %% [markdown]
# **__init__ method in Python**
#
# The __init__ method in Python is a special method called a constructor. It is automatically invoked when a new instance (object) of a class is created. The purpose of the __init__ method is to initialize the object’s attributes and perform any other setup necessary when an object is instantiated.
#
# Note:
#
# using mangling we can access any private or protected method in python
#
# default constructor:
#
# parameterized constructor: constructor with parameters is known as parameterized constructor. The parameterized constructor takes its first argument as a reference to the instance being constructed known as self and the rest of the arguments are provided by the programmer.

# %% [markdown]
# __Str__ Method
#
#  that is used to define how a class object should be represented as a string.

# %%
class Car():

    # init method or constructor
    def __init__(self, model, color):
        self.model = model
        self.color = color

    def show(self):
        print("Model is", self.model )
        print("color is", self.color )

    def __str__(self):
        return f"Car(model={self.model}, color={self.color})"

# both objects have different self which contain their attributes
audi = Car("audi a4", "blue")
ferrari = Car("ferrari 488", "green")

audi.show()     # same output as car.show(audi)
ferrari.show()  # same output as car.show(ferrari)


print("Model for audi is ",audi.model)
print("Colour for ferrari is ",ferrari.color)
print(audi)  # Output: Car(model=audi a4, color=blue)
print(ferrari)  # Output: Car(model=ferrari 488, color=

# %%
class Car:

  def __init__(self):
    self.name = 'sanjay'
    self.age = 24


  def __str__(self):
    return f'name {self.name} & age {self.age}'


c = Car()
print(c)

# %% [markdown]
# __new__ (Object Creation)
# Purpose: __new__ is responsible for creating a new instance of a class. It is the method that is called first when you create a new object.
#
# Behavior: It is a static method that returns a new instance of the class (or another class, in the case of metaclasses or custom object creation). It is called before the __init__ method.
#
# __init__ (Object Initialization)
# Purpose: __init__ is the constructor method that initializes the attributes of the object after it is created by __new__. It's responsible for setting up the object's state.
#
# ## __new__ vs __init__
#
# __new__ is responsible for creating and returning a new object instance, while __init__ initializes the object's attributes after it has been created.
#
# ## __str__ vs __repr__
#
# __str__ provides a readable string representation for users, while __repr__ provides an official string representation mainly for debugging and developers.
#
# The __call__ method allows an instance of a class to be called like a function. When we use parentheses on an object, Python internally calls the __call__ method.
#
# __slots__ is used to restrict attribute creation and reduce memory usage by preventing the creation of a dynamic __dict__ for each object.

# %% [markdown]
# **Python Inheritance**
#
# Inheritance is the capability of one class to derive or inherit the properties from another class.
#
# The class that derives properties is called the derived class or child class and the class from which the properties are being derived is called the base class or parent class.
#
# benfits
#
# 1.It represents real-world relationships well.
#
# 2.It provides the reusability of a code. We don’t have to write the same code again and again. Also, it allows us to add more features to a class without modifying it.
#
# 3.It is transitive in nature, which means that if class B inherits from another class A, then all the subclasses of B would automatically inherit from class A.

# %% [markdown]
# ## **Types of Inheritance**
#
# **Single Inheritance:** Single-level inheritance enables a derived class to inherit characteristics from a single-parent class.
#
# **Multilevel Inheritance:** Multi-level inheritance enables a derived class to inherit properties from an immediate parent class which in turn inherits properties from his parent class.
#
# **Hierarchical Inheritance:** Hierarchical-level inheritance enables more than one derived class to inherit properties from a parent class.
#
# **Multiple Inheritance:**  Multiple-level inheritance enables one derived class to inherit properties from more than one base class.

# %%
# Python code to demonstrate how parent constructors
# are called.

# parent class
class Person(object):

    # __init__ is known as the constructor
    def __init__(self, name, idnumber):
        self.name = name
        self.idnumber = idnumber

    def display(self):
        print(self.name)
        print(self.idnumber)

    def details(self):
        print("My name is {}".format(self.name))
        print("IdNumber: {}".format(self.idnumber))

# child class
class Employee(Person):
    def __init__(self, name, idnumber, salary, post):
        self.salary = salary
        self.post = post

        # invoking the __init__ of the parent class
        Person.__init__(self, name, idnumber)

    def details(self):
        print("My name is {}".format(self.name))
        print("IdNumber: {}".format(self.idnumber))
        print("Post: {}".format(self.post))


# creation of an object variable or an instance
a = Employee('Rahul', 886012, 200000, "Intern")

# calling a function of the class Person using
# its instance
a.display()
a.details()

# %% [markdown]
# **Super()**
# is a built-in Python function that returns a temporary object of the parent (super) class, allowing a child class to access its methods and constructor.
#
# super() helps avoid directly calling the parent class name and supports clean multiple inheritance.

# %%
# Python program to demonstrate
# calling the parent's class method
# inside the overridden method using
# super()
class Parent():

    def show(self):
        print("Inside Parent")

class Child(Parent):

    def show(self):

        # Calling the parent's class
        # method
        super().show()
        print("Inside Child")

# Driver's code
obj = Child()
obj.show()

# %% [markdown]
# ## What is Method Resolution Order (MRO)?
#
# MRO is the order in which Python looks for a method or attribute in a class hierarchy when multiple inheritance is involved. It defines which method is called first when there are multiple methods with the same name.
#
# Python uses the C3 linearization algorithm (also called C3 superclass linearization) to compute MRO:
#
# Starts from the class itself.
#
# Then looks in base classes from left to right in the inheritance list.
#
# Preserves local precedence order and monotonicity (a subclass always comes before its parent).

# %%
class A:
    def show(self):
        print("A")

class B(A):
    def show(self):
        print("B")

class C(A):
    def show(self):
        print("C")

class D(B, C):
    pass

d = D()
d.show()  
print(D.__mro__)

# %% [markdown]
# ## What is the Diamond Problem, and how does Python solve it with super()?
#
# Answer (Flash Version):
# The Diamond Problem occurs in multiple inheritance when a class inherits from two classes that share a common ancestor, leading to ambiguity in which parent’s method should be called.
#
# Python solves this using:
#
# Method Resolution Order (MRO) – a linear order of classes computed via C3 linearization.
#
# super() – ensures that each method in the hierarchy is called only once, following the MRO

# %% [markdown]
# **What is polymorphim ?**
#
# Polymorphism means “many forms.” In object-oriented programming, it refers to the ability of a method, function, or operator to behave differently based on the object or context in which it is used.
#
# **Method Overriding**
#
# Method overriding is a concept in OOP where a child class provides its own implementation of a method that is already defined in the parent class. The method name, parameters, and return type must be the same. It is mainly used to achieve runtime polymorphism.
#
# **Method overloading**
#
# Method overloading refers to the ability to have multiple methods with the same name but different parameters within the same class. Python does not support method overloading by default. However, we can achieve method overloading-like behavior by providing default values for parameters or by using variable-length arguments.

# %%
class India():
    def capital(self):
        print("New Delhi is the capital of India.")

    def language(self):
        print("Hindi is the most widely spoken language of India.")

    def type(self):
        print("India is a developing country.")

class USA():
    def capital(self):
        print("Washington, D.C. is the capital of USA.")

    def language(self):
        print("English is the primary language of USA.")

    def type(self):
        print("USA is a developed country.")

def func(obj):
    obj.capital()
    obj.language()
    obj.type()

obj_ind = India()
obj_usa = USA()

func(obj_ind)
func(obj_usa)

# %% [markdown]
# **what is Encapsulation?**
#
# Encapsulation is an OOP concept where we bind data and methods together inside a class and hide the internal details of the object. It exposes only what is necessary through a public interface and prevents direct access to the object's data from outside the class.
#
#
# Encapsulation in Python is implemented using access specifiers to control access to class members:
#
# Public Members: By default, attributes and methods are public and can be accessed from outside the class.
#
#
# Protected Members: Use a single underscore (_) prefix to indicate that an attribute or method is intended for internal use within the class and its subclasses.
#
#
# Private Members: Use double underscores (__) prefix to make an attribute or method private. This leads to name mangling, making it more challenging to access from outside the class.
#
#
# Private Members: Members with double underscores (__) are private. They are intended to be accessed only within the class where they are defined. Python uses name mangling to make these members harder to access from outside the class.
#
# Protected Members: Members with a single underscore (_) are protected. They are intended for use within the class and its subclasses. This is a convention and does not enforce strict access control.

# %%
# Python program to
# demonstrate private members

# Creating a Base class


class Base:
    def __init__(self):
        self.a = "GeeksforGeeks"
        self.__c = "GeeksforGeeks"

# Creating a derived class
class Derived(Base):
    def __init__(self):

        # Calling constructor of
        # Base class
        Base.__init__(self)
        print("Calling private member of base class: ")
        print(self.__c)


# Driver code
obj1 = Base()
print(obj1.a)
print(obj1._Base__c)  # access the “private” attribute via name‑mangling
# Uncommenting print(obj1.c) will
# raise an AttributeError

# Uncommenting obj2 = Derived() will
# also raise an AttributeError as
# private member of base class
# is called inside derived class

# %% [markdown]
# # Abstraction
#
# Abstraction is used to hide the internal functionality of the function from the users. The users only interact with the basic implementation of the function.
#
# A class that contains one or more abstract methods is called an abstract class.
#
# An abstract method is a method that has a declaration but does not have an implementation.
#
# Concrete Methods in Abstract Base Classes
# Concrete classes contain only concrete (normal) methods whereas abstract classes may contain both concrete methods and abstract methods.
#
# Adv
#
# Enforcing a Contract:
# Code Reusability:
# Encouraging Design Principles: Promote the use of design patterns and principles like SOLID.
# Reducing Code Duplication:
# Improved Readability and Maintainability:

# %%
# Python program showing
# abstract base class work
from abc import ABC, abstractmethod


class Animal(ABC):
    @abstractmethod
    def move(self):
        pass

class Human(Animal):

     def move(self):
         print("I can walk and run")

class Snake(Animal):

    def move(self):
        print("I can crawl")

class Dog(Animal):

    def move(self):
        print("I can bark")

class Lion(Animal):

    def move(self):
        print("I can roar")

# Driver code
R = Human()
R.move()

K = Snake()
K.move()

R = Dog()
R.move()

K = Lion()
K.move()

# %% [markdown]
# # **Iterator**
#
# An iterator in Python is an object that is used to iterate over iterable objects like lists, tuples, dicts, and sets. The Python iterators object is initialized using the iter() method. It uses the next() method for iteration.

# %%
string = "GFG"
ch_iterator = iter(string)

print(next(ch_iterator))
print(next(ch_iterator))
print(next(ch_iterator))
print(next(ch_iterator))

# %% [markdown]
# # **pass**
#
# The pass statement is also know as null operation; it does nothing. It's used as a placeholder when you need syntactically correct code but don't want to execute any statements.
#
# pass used to create empty calss ,methods and condition

# %%
class Test:
  pass

# %% [markdown]
# # **sequence data type**
#
# **String**
#
# A String is a data structure in Python Programming that represents a sequence of characters.
#
# It is an immutable data type, meaning that once created a string,it cannot modify it.
#
# string supports indexing and slicing foam to access the character
#
# We can create a string by enclosing the characters in single-quotes or double- quotes and triple qoutes(used in docstrings which contain code)

# %% [markdown]
# **Python Lists**
#
#
# list is ordered collection of items,where mutiple values are stord in one variable which is enclosed by [] and separated by commas.
#
#
# list is mutable type and dynamically scaled arrays
#
# list uses Indexing and  slice operator to access the element
#
# list are a heterogeneous  sequence means it can store multi data type

# %% [markdown]
# **Tuple**
#
# tuple is ordered collection of items, mutiple values are stord in one variable which is enclosed by () and separated by commas.
#
# It is an immutable data type, meaning that once created a tuple,it cannot modify
# its element value and size.
#
# tuple  are a heterogeneous  sequence means it can store multi data type

# %% [markdown]
# **List Vs Tuple**
#
# list is enclosed by [] and tupel is enclosed by ()
#
# list is dynamic in size and tuple is in satic size
#
# tuple little more memory-efficient than lists
#
# list have more opeation fun when compared with tuple and adding removing and updating orperation

# %% [markdown]
# **Set**
#
# A Python set is the collection of the unordered items. Each element in the set must be unique,
#
# Sets are mutable which means we can modify it after its creation.
#
# sets dont store the data in index So we cannot access it though indexing
#
# A Python set is heterogeneous, meaning it can store different data types together, but all elements must be unique and hashable.

# %% [markdown]
# A Python set uses a hash table. Each element is hashed to compute an index, ensuring unique storage and allowing O(1) average lookup, insertion, and deletion.

# %% [markdown]
# **Dictionaries**
#
# in Python is a data structure, used to store values in key: value format. This makes it different from lists, tuples, and arrays as in a dictionary each key has an associated value.
#
# This data structure is mutable
#
# Keys must only have one component.
#
# Values can be of any type, including integer, list, and tuple.

# %% [markdown]
# A Python dictionary uses a hash table. Keys are hashed to compute an index, and values are stored at that index. Collisions are handled with probing, giving average O(1) lookup, insertion, and deletion.

# %% [markdown]
# Array
#
# An array is a collection of items stored at contiguous memory locations.
#
# they are mutable and dynamic in size
#
# they can store only same data type
#
# to use array we need to import array module

# %% [markdown]
# # List Vs Array
#
# A list can store different data types in a single collection, whereas an array can store only elements of the same data type.
#
# A list consumes more memory because it stores references and type information, whereas an array is more memory efficient.
#
# A list provides many built-in methods and is highly flexible, whereas an array supports fewer operations.
#
# A list is mainly used for general-purpose programming, whereas an array is preferred for handling large numeric data efficiently.

# %% [markdown]
# # Mutable vs Immutable
#
# Mutable objects can be modified after creation, while immutable objects cannot. Internally, immutable objects create a new memory location when modified, whereas mutable objects modify the same memory location.

# %% [markdown]
# # Pass vs Reference
#
# Python uses pass-by-object-reference. The function receives a reference to the object. If the object is mutable, changes inside the function affect the original object. If it is immutable, a new object is created and the original remains unchanged.

# %% [markdown]
# # Shallow Copy vs deep copy
#
# Object Level: Shallow copy duplicates only the outer object, while deep copy duplicates both the outer object and all nested objects.
#
# Effect of Changes: In shallow copy, changes to nested mutable objects affect both copies, whereas in deep copy, changes do not affect the original.
#
# Performance & Memory: Shallow copy is faster and memory-efficient, while deep copy is slower and consumes more memory because it creates full independent copies.

# %% [markdown]
# # copy vs slicing
#
# Both copy() and slicing ([:]) create shallow copies of a list. The difference is that copy() is a method and more explicit, while slicing is a sequence operation. Both share nested object references.

# %% [markdown]
# # **List Comprehension**
#
# List comprehension in Python is an efficient way to create lists. It allows us to generate new lists by applying an expression to each item in a sequence or iterable. It optionally filters items to include only those that meet a certain condition. It’s a more syntactically compact and readable alternative to using loops for list creation.

# %%
numbers = [1, 2, 3, 4]

squares = [x * x for x in numbers]

print(squares)

# %% [markdown]
# # **Python Functions**
#
# A function is a block of code that performs a specific task.
#
# When a defined function is called, a return statement is written to exit the function and return the calculated value.
#
# Adv
#
# Increase Code Readability
# Increase Code Reusability
#
# **Types of Functions in Python**
#
# - **Built-in library function:** These are Standard functions in Python that are available to use.
#
# - **User-defined function**: We can create our own functions based on our requirements.
#
# - Lambda functions
#
# - Recursive functions
#
# **Function Arguments**
#
# - Default arguments
# - Keyword arguments
# - positional
# - Variable-length arguments
#
# A default argument is a parameter that assumes a default value if a value is not provided in the function call for that argument.
#
# The idea is to allow the caller to specify the argument name with values so that the caller does not need to remember the order of parameters.
#
# Required arguments are those supplied to a function during its call in a predetermined positional sequence.
#
# In Python Arbitrary Keyword Arguments, *args, and **kwargs can pass a variable number of arguments to a function using special symbols. There are two special symbols:
#
# *args in Python (Non-Keyword Arguments)
# **kwargs in Python (Keyword Arguments)
#
# The Anonymous Functions
# Since we do not use the def keyword to declare these kinds of Python functions, they are unknown. The lambda keyword can define anonymous, short, single-output functions.

# %% [markdown]
# # first class function
#
# In Python, functions are first-class objects, meaning they can be assigned to variables, passed as arguments, returned from other functions, and stored in data structures. This allows higher-order functions, callbacks, and functional programming

# %%
def greet(name): return f"Hello, {name}"
say_hello = greet
print(say_hello("Sanjay"))  # Output: Hello, Sanjay

# %% [markdown]
# # high order function
#
# A higher-order function is a function that can take other functions as arguments or return a function. They are possible because Python treats functions as first-class objects.

# %%
def greet(name):
    return f"Hello, {name}"

def executor(func, value):  # func is passed as argument
    return func(value)

print(executor(greet, "Sanjay"))  # Output: Hello, Sanjay

# %% [markdown]
# **Lambda function**
#
# A lambda function in Python is a small anonymous function defined using the lambda keyword, used for short one-line operations, commonly with functions like map, filter, and sorted.

# %%
x = lambda a: a+10
print(x(10))

# %% [markdown]
# # map function
#
# map() applies a function to each element of an iterable and returns an iterator. It is commonly used for transforming data.

# %%
nums = [1, 2, 3, 4]
result = map(lambda x: x * 2, nums)

print(list(result))

# %% [markdown]
# # filter function
# filter() is used to select elements from an iterable based on a condition. It returns an iterator containing only the elements for which the function returns True.

# %%
# filter()
list(filter(lambda x: x > 2, nums))

# list comprehension
[x for x in nums if x > 2]

# %% [markdown]
# # reduce function
#
# The reduce() function applies a function cumulatively to the elements of an iterable, reducing it to a single value. It is used for operations like summing, multiplying, or combining elements.

# %%
from functools import reduce
import operator

numbers = [1, 2, 3, 4]
result = reduce(operator.mul, numbers)
print(result)   # 24

# %% [markdown]
# # accumulate funtion
#
# The accumulate() function returns cumulative results of an operation on elements of an iterable. By default it sums, but it can perform other operations using a custom function. It provides all intermediate results as an iterator.

# %%
from itertools import accumulate
import operator

numbers = [1, 2, 3, 4]
result = list(accumulate(numbers, operator.mul))
print(result)

# %% [markdown]
# ## map() vs List Comprehension
#
# Syntax & Readability: List comprehension is more readable and Pythonic, while map() can look less clear, especially with lambda functions.
#
# Function Requirement: map() requires a function as the first argument, whereas list comprehension allows inline expressions directly.
#
# Flexibility: List comprehension supports filtering using if conditions easily, while map() does not support filtering directly (you need filter() separately).
#
# Performance: List comprehension is generally slightly faster in Python because it is optimized and avoids function call overhead (especially when using lambda with map()).

# %% [markdown]
# ## Modules in Python
#
#
# A module is a file containing Python code, definitions of functions, statements, or classes.
#
# We employ modules to divide complicated programs into smaller, more understandable pieces. Modules also allow for the reuse of code.
#
# a module can be primarily written in C programming language and then dynamically inserted at run-time.

# %% [markdown]
# ## What is a Closure?
#
# A closure is a function that remembers the values from its enclosing scope, even after the outer function has finished execution. It occurs when an inner function accesses variables of an outer function and the outer function returns the inner function.

# %%
def counter():
    count = 0
    def increment():
        nonlocal count
        count += 1
        return count
    return increment

c = counter()
print(c())  # 1
print(c())  # 2
print(c())  # 3

# %% [markdown]
# ## Decorators
# are one of the most helpful and powerful tools of Python. These are used to modify the behavior of the function. Decorators provide the flexibility to wrap another function to expand the working of wrapped function, without permanently modifying it.
#
# In Decorators, functions are passed as an argument into another function and then called inside the wrapper function.
#
# It is also called meta programming where a part of the program attempts to change another part of program at compile time.

# %%
def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

@my_decorator
def hello_world():
  print('hello')

hello_world()

# %% [markdown]
# # Built in Decoratprs
#
# ## @staticmethod
#
# Defines a method that belongs to a class but does not access class or instance variables.
#
# When the method performs a utility task related to the class but does not need self or cls.

# %%
class MathUtils:
    @staticmethod
    def add(a, b):
        return a + b

# %% [markdown]
# ## @classmethod
#
# Defines a method that takes the class (cls) as the first parameter instead of the instance.
#
# When you need to access or modify class-level variables.

# %%
class Employee:
    company = "ABC"

    @classmethod
    def change_company(cls, name):
        cls.company = name

# %% [markdown]
# # @property
#
# Converts a method into a read-only attribute.
#
# To implement getter functionality and encapsulation.

# %%
class Person:
    def __init__(self, age):
        self._age = age

    @property
    def age(self):
        return self._age
    
p = Person(25)
print(p.age)   # No parentheses


class Person:
    def __init__(self, age):
        self._age = age

    @property
    def age(self):
        return self._age

    @age.setter
    def age(self, value):
        if value < 0:
            raise ValueError("Age cannot be negative")
        self._age = value

    @age.deleter
    def age(self):
        del self._age

# %% [markdown]
# ## @abstractmethod
#
# Forces child classes to implement the method.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

# %% [markdown]
# ## dataclass
#
# is a Python decorator that automatically generates boilerplate methods like __init__, __repr__, and __eq__ for classes used to store data.
# It makes code shorter, cleaner, and more readable.
# You can make instances immutable with frozen=True and provide default values for fields.

# %%
from dataclasses import dataclass

@dataclass
class Employee:
    name: str
    age: int
    salary: float = 0.0  # default value

e1 = Employee("Sanjay", 30, 50000)
print(e1)  # Output: Employee(name='Sanjay', age=30, salary=50000)

# %% [markdown]
# ## Generator
#
# a generator is a special type of iterator that allows you to iterate over a sequence of values lazily. Unlike regular functions that return a single value and terminate, generators use the yield keyword to produce a series of values, one at a time, which can be iterated over. They are useful when you need to handle large datasets or streams of data without loading everything into memory at once.
#
# Advantages of Generators
#
# Generators are easy to implement as compared to the iterator. In iterator, we have to implement __iter__() and __next__() function
#
# Memory efficient

# %%
def count_up_to(max):
    count = 1
    while count <= max:
        yield count
        count += 1

for i in count_up_to(10):
    print(i)

# %% [markdown]
# ## Exception
#
# an exception is an event that disrupts the normal flow of a program's execution. It occurs when the interpreter encounters an error during runtime, which causes the program to stop executing the current block of code.
#
# try and expect
#
# In Python, we catch exceptions and handle them using try and except code blocks.
#
# The try block contains the code that can raise an exception, while the except
# handles contains the code lines that handle the exception
#
# Raise Exeption
#
# If a condition does not meet our criteria but is correct according to the Python interpreter, we can intentionally raise an exception using the raise keyword.
#
# Assertion error
#
# preferably true when it finds an assert statement. Python throws an AssertionError exception if the result of the expression is false.
#
# else:
# it will execute if try block not throw error
#
# finally:
# it will execute after try and exepct block
#
#
# syntaxError, TypeError, ValueError, IndexError AttributeError:
#
# ZeroDivisionError:
# IndexError:

# %%
try:
    num = int(input("Enter a number: "))
    result = 10 / num

except ZeroDivisionError:
    print("You cannot divide by zero!")

except ValueError:
    print("Invalid input! Please enter a number.")

else:
    print("Result is:", result)

finally:
    print("Execution completed.")

# %% [markdown]
# ## User-Defined Exceptions
#
# User-defined exceptions are created by inheriting from the Exception class, and they allow us to define custom error conditions specific to business logic.

# %%
class InvalidAgeError(Exception):
    pass


try:
    age = int(input("Enter your age: "))
    
    if age < 18:
        raise InvalidAgeError("Age must be 18 or above.")

except InvalidAgeError as e:
    print("Custom Exception:", e)

except ValueError:
    print("Please enter a valid number.")

else:
    print("Age is valid. You are eligible.")

finally:
    print("Execution completed.")

# %% [markdown]
# # Multiprocessing
#
# Multiprocessing in Python allows parallel execution using multiple processes, each with its own memory space. It is mainly used for CPU-bound tasks to bypass the GIL and utilize multiple CPU cores efficiently.

# %%
from multiprocessing import Process
import os

def print_process():
    print("Process ID:", os.getpid())

if __name__ == "__main__":
    p1 = Process(target=print_process)
    p2 = Process(target=print_process)

    p1.start()
    p2.start()

    p1.join()
    p2.join()

# %% [markdown]
# ## Multithreading
#
#
# Multithreading is a technique where multiple threads run within the same process to perform tasks concurrently.
# All threads share the same memory space.

# %%
import threading
import time

def task():
    print("Task started")
    time.sleep(2)
    print("Task finished")

t1 = threading.Thread(target=task)
t2 = threading.Thread(target=task)

t1.start()
t2.start()

t1.join()
t2.join()

# %% [markdown]
# ## Thread safety
# Thread safety ensures that shared resources are accessed correctly when multiple threads run concurrently. It prevents race conditions by using synchronization mechanisms like locks.

# %% [markdown]
# ## Race Condition
#
# A race condition occurs when two or more threads access and modify shared data at the same time, and the final result depends on the order of execution.
#
# Because thread execution order is unpredictable, the output becomes inconsistent.

# %% [markdown]
# # Asyncio
#
# Asyncio is a Python library for asynchronous programming that uses async and await to run multiple I/O-bound tasks concurrently using a single-threaded event loop.

# %%
import asyncio

async def task(name):
    print(f"{name} started")
    await asyncio.sleep(2)
    print(f"{name} finished")

async def main():
    await asyncio.gather(
        task("Task 1"),
        task("Task 2")
    )

asyncio.run(main())

# %% [markdown]
# # What is Reference Counting?
#
# Python uses reference counting for memory management. Each object keeps track of how many references point to it. When the reference count drops to zero, the object is immediately deleted. To handle circular references, Python also uses a generational garbage collector.

# %%
import sys

a = [1, 2, 3]
print(sys.getrefcount(a))  # shows reference count

# %% [markdown]
# ## What is Garbage Collection?
#
# Garbage Collection is the process of automatically freeing memory that is no longer in use.
#
# In Python, GC works along with reference counting to manage memory.

# %% [markdown]
# # Stack vs heap memory
#
# What is Stored: Stack stores function calls and reference variables, while heap stores the actual objects and data.
#
# Memory Management: Stack is automatically managed in LIFO order, whereas heap memory is managed by reference counting and garbage collection.
#
# Speed: Stack access is faster because it follows a fixed allocation pattern, while heap allocation is slightly slower due to dynamic memory management.
#
# Size & Lifetime: Stack memory is limited and exists only during function execution, while heap memory is dynamic in size and objects remain until they are garbage collected.

# %% [markdown]
# # **How is memory managed in Python?**
#
# Python manages memory automatically through the use of a private heap containing all Python objects and data structures. The key components of Python’s memory management include automatic garbage collection, memory pools, and dynamic typing.
#
# Python utilizes reference counting to detect and reclaim memory from unused objects, along with a cyclic garbage collector to free up circular references.
#
# pymalloc(Python memory allocator) algorithm to minimize overhead.
#
# the memory allocation and deallocation for objects are handled dynamically, ensuring efficient memory use and reducing memory waste.

# %% [markdown]
# # **Explain the GIL in Python and its implications.**
#
#
#
# The GIL, or Global Interpreter Lock, is a mechanism used in CPython (the standard Python implementation) to ensure that only one thread executes Python bytecode at a time.
#
# This lock is necessary because CPython’s memory management is not thread-safe.
# which could lead to race conditions and corrupt data structures.
#
# The main implication of the GIL is that it limits the execution of multi-threaded Python programs on multi-core processors.

# %% [markdown]
# # **What is a metaclass in Python, and why would you use it?**
#
# A metaclass in Python is a class of a class that defines how a class behaves. A class is an instance of a metaclass, just as an object is an instance of a class. Metaclasses are used to create classes with specific traits or behaviors, allowing for more dynamic and flexible object-oriented programming.

# %% [markdown]
# # **What is an Interpreted language?**
#
# An Interpreted language executes its statements line by line. Languages such as Python, Javascript, R, PHP, and Ruby are prime examples of Interpreted languages. Programs written in an interpreted language runs directly from the source code, with no intermediary compilation step.

# %% [markdown]
# # **What is pickling and unpickling?**
#
# Pickling:
#
# Pickling is the name of the serialization process in Python. Any object in Python can be serialized into a byte stream and dumped as a file in the memory.
#
# The function used for the above process is pickle.dump()
#
# UnPickling:
#
# Unpickling is the complete inverse of pickling. It deserializes the byte stream to recreate the objects stored in the file and loads the object to memory.
# The function used for the above process is pickle.load().
